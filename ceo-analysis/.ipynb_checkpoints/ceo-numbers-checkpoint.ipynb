# %%
import pandas as pd

# %%
data = pd.read_json('https://interactives.dallasnews.com/data-store/2018/2018-06-ceo-pay-tracker.json')

# %%
data
# Out:
#                                     ceoname  \
# 0                              Ed Heffernan
# 1                               Doug Parker
# 2                        Randall Stephenson
# 3                      Lewis (Lee) Bird III
# 4                       Douglas A. Kessler
# 5                               Kim Cocklin
# 6                        Thomas E. Ferguson
# 7                     T. M. “Roe” Patterson
# 8                          Richard Stockton
# 9                             Wyman Roberts
# 10                            Floyd Sherman
# 11                           Lawrence Cohen
# 12                         Dennis Sadlowski
# 13                                Mark Rohr
# 14                                Joe Armes
# 15                          Ralph Babb Jr.
# 16                          Joseph Alvarado
# 17                                Jay Adair
# 18                              Mark Zoradi
# 19                        Gary J. Wojtaszek
# 20                          Daniel L. Jones
# 21                      John W. McReynolds
# 22                            Keith Walters
# 23                           Barry E. Davis
# 24                             Kenneth Rees
# 25                            Harold Hickey
# 26                             Darren Woods
# 27                           Ronald Cogburn
# 28                        Randall C. Stuewe
# 29                               Don Daseke
# ..                                      ...
# 72                               Brad Mason
# 73                       Michael Willoughby
# 74                           Alasdair James
# 75                          Timothy L. Dove
# 76                            David L. King
# 77                       Jeffrey L. Ventura
# 78                          Stephen T. Winn
# 79                             Mark Speese*
# 80                              Steven Gray
# 81                               Sean Menke
# 82                       Christian Brickman
# 83                             Scott Powell
# 84   James Reid-Anderson and John M. Duffey
# 85                         Bruce Williamson
# 86                               Gary Kelly
# 87                            Jackson Hsieh
# 88                    Ronald A. Rittenmeyer
# 89                         C. Keith Cargill
# 90                           Rich Templeton
# 91                             Melissa Raff
# 92                            David Weinreb
# 93                          Gary L. Coleman
# 94                       Larry M. Hutchison
# 95                       Timothy R. Wallace
# 96                            Steven Becker
# 97                         John S. Marr Jr.
# 98                        William Sandbrook
# 99                         Robert D. Graham
# 100                        Curtis A. Morgan
# 101                             Kevin Miles
#
#                                               ceonotes  ceopay2017  \
# 0                                                  NaN  10882813.0
# 1                                                  NaN  12175146.0
# 2                                                  NaN  28720720.0
# 3    At Home is an Emerging Growth Company (EGC) fi...   9506168.0
# 4    Kessler became the CEO in February 2017. Monty...   4774099.0
# 5    CEO pay ratio disclosure is required for the f...   4649187.0
# 6                                                  NaN   3684992.0
# 7                                                  NaN  12045210.0
# 8    The company is an emerging company that does n...    125816.0
# 9                                                  NaN   5102318.0
# 10       Sherman retired effective December 29, 2017.    3748466.0
# 11                                                 NaN   3034193.0
# 12   Sadlowski became interim CEO in February 2017 ...   1253000.0
# 13                                                 NaN  11919628.0
# 14   The CEO pay ratio and median employee pay were...   3037424.0
# 15                                                 NaN  12095114.0
# 16                                                 NaN  15464253.0
# 17   Adair agreed to forgo all salary and bonus com...     34691.0
# 18                                                 NaN   4489820.0
# 19                                                 NaN   7025803.0
# 20                                                 NaN   2149259.0
# 21   The company uses McReynolds for purposes of th...   1367413.0
# 22   Ennis Inc.'s fiscal year ends on February 28, ...   3036021.0
# 23   Davis was the CEO until Michael Garberding was...   6800000.0
# 24                                                 NaN   5337535.0
# 25                                                 NaN   4507169.0
# 26                                                 NaN  17466133.0
# 27                                                 NaN    325000.0
# 28                                                 NaN   6443577.0
# 29                                                 NaN   1220133.0
# ..                                                 ...         ...
# 72                                                 NaN   4705758.0
# 73                                                 NaN   1803543.0
# 74                                                 NaN   4064959.0
# 75                                                 NaN  10934244.0
# 76                                                 NaN   1765660.0
# 77   The company rounded the CEO pay up to $8.7 mil...   8656866.0
# 78                                                 NaN   9143250.0
# 79   Since Mark Speese served as CEO for less than ...   1164660.0
# 80                                                 NaN   8550199.0
# 81                                                 NaN   6946628.0
# 82                                                 NaN   4162710.0
# 83                                                 NaN   2696513.0
# 84   Six Flags used the combined salary of the two ...  15013033.0
# 85                                                 NaN   1016827.0
# 86                                                 NaN   7560200.0
# 87                                                 NaN  10783397.0
# 88                                                 NaN   5200001.0
# 89                                                 NaN   3612644.0
# 90                                                 NaN  16573019.0
# 91   The Container Store is a controlled company, s...   1631000.0
# 92                                                 NaN   7195875.0
# 93   The company has co-CEOs and used Coleman's com...   8373156.0
# 94                           The company has co-CEOs.    8311946.0
# 95                                                 NaN   8954976.0
# 96                                                 NaN   2100796.0
# 97                                                 NaN   3725092.0
# 98                                                 NaN   3631663.0
# 99                                                 NaN   3875230.0
# 100  Median employee and ratio data was not require...   8034153.0
# 101                                                NaN   2743974.0
#
#                                              company  employeeratio  \
# 0                              Alliance Data Systems         145.00
# 1                                  American Airlines         195.00
# 2                                               AT&T         366.00
# 3                                            At Home            NaN
# 4                                Ashford Hospitality            NaN
# 5                                       Atmos Energy            NaN
# 6                                                AZZ          39.00
# 7                              Basic Energy Services         177.00
# 8                          Braemar Hotels & Resorts             NaN
# 9                                            Brinker            NaN
# 10                              Builders FirstSource          69.00
# 11                             Capital Senior Living         155.00
# 12                           CECO Environmental Corp          26.00
# 13                                         Celanese          157.00
# 14                                   CSW Industrials            NaN
# 15                                      Comerica Inc         152.00
# 16                                 Commercial Metals            NaN
# 17                                            Copart            NaN
# 18                                          Cinemark         752.00
# 19                                          CyrusOne          67.00
# 20                                       Encore Wire          42.00
# 21   Energy Transfer Equity/Energy Transfer Partners          12.00
# 22                                         Ennis Inc            NaN
# 23        EnLink Midstream/EnLink Midstream Partners          61.00
# 24                                   Elevate Credit             NaN
# 25                                    EXCO Resources            NaN
# 26                                       Exxon Mobil         108.00
# 27                                Exela Technologies            NaN
# 28                               Darling Ingredients         136.00
# 29                                        Daseke Inc            NaN
# ..                                               ...            ...
# 72                            Orthofix International          74.00
# 73                                            PFSweb          75.00
# 74                                    Pier 1 Imports         618.00
# 75                         Pioneer Natural Resources          92.00
# 76                                 Primoris Services          33.00
# 77                                   Range Resources          70.00
# 78                                          RealPage         194.00
# 79                                     Rent-a-Center          42.00
# 80                                       RSP Permian          62.00
# 81                                             Sabre         100.00
# 82                                      Sally Beauty            NaN
# 83                               Santander Consumer           49.00
# 84                           Six Flags Entertainment        1804.00
# 85                                 Southcross Energy            NaN
# 86                                Southwest Airlines          93.00
# 87                             Spirit Realty Capital         113.79
# 88                                  Tenet Healthcare         102.00
# 89                          Texas Capital Bancshares          39.60
# 90                                 Texas Instruments         210.00
# 91                               The Container Store            NaN
# 92                            The Howard Hughes Corp         118.00
# 93                                         Torchmark         104.00
# 94                                         Torchmark         103.00
# 95                                Trinity Industries         253.00
# 96                                   Tuesday Morning            NaN
# 97                                Tyler Technologies          45.40
# 98                                     U.S. Concrete          49.70
# 99                                             Valhi          90.00
# 100                                    Vistra Energy            NaN
# 101                                    Zoe's Kitchen         185.00
#
#     employeesCountedInRatio  medianpay multipleceos  \
# 0                       NaN    75232.0          NaN
# 1                    138512    62394.0          NaN
# 2                    244248    78437.0          NaN
# 3                       NaN        NaN          NaN
# 4                       NaN        NaN          NaN
# 5                       NaN        NaN          NaN
# 6                      4407    44492.0          NaN
# 7                      4093    68175.0          NaN
# 8                         0        NaN          NaN
# 9                       NaN        NaN          NaN
# 10                    15050    54661.0          NaN
# 11                      NaN    19557.0          NaN
# 12                      923    48900.0          NaN
# 13                     7597    75928.0          NaN
# 14                      NaN        NaN          NaN
# 15                     8163    79951.0          NaN
# 16                      NaN        NaN          NaN
# 17                      NaN        NaN          NaN
# 18                    26957     5971.0          NaN
# 19                      415   105172.0          NaN
# 20                      NaN    51113.0          NaN
# 21                     8494   115226.0          NaN
# 22                      NaN        NaN          NaN
# 23                     1494   111319.0          NaN
# 24                      NaN        NaN          NaN
# 25                      NaN        NaN          NaN
# 26                      NaN   161562.0          NaN
# 27                      NaN        NaN          NaN
# 28                      NaN    47375.0          NaN
# 29                      NaN        NaN          NaN
# ..                      ...        ...          ...
# 72                      NaN    63664.0          NaN
# 73                     3010    24199.0          NaN
# 74                      NaN     6580.0          NaN
# 75                      NaN   118769.0          NaN
# 76                      NaN    54080.0          NaN
# 77                      NaN   123500.0          NaN
# 78                      NaN    41288.0          NaN
# 79                      NaN    27439.0          NaN
# 80                      NaN   137344.0          NaN
# 81                     8521    69656.0          NaN
# 82                      NaN        NaN          NaN
# 83               not listed    54483.0          NaN
# 84               not listed     8322.0          yes
# 85                      NaN        NaN          NaN
# 86                    59387    81177.0          NaN
# 87                       87    94760.0          NaN
# 88                   124086    50922.0          NaN
# 89                      NaN    91315.0          NaN
# 90                    29973    78951.0          NaN
# 91                     5100        NaN          NaN
# 92                      NaN    61177.0          NaN
# 93                      NaN    80680.0          NaN
# 94                      NaN    80680.0          NaN
# 95                    14958    35443.0          NaN
# 96                      NaN        NaN          NaN
# 97                     4125    82039.0          NaN
# 98                      NaN    73034.0          NaN
# 99               not listed    42906.0          NaN
# 100                     NaN        NaN          NaN
# 101              over 5,000    14800.0          NaN
#
#                            photo                      sector  \
# 0                   _edheffernan      Consumer Discretionary
# 1                    _dougparker      Consumer Discretionary
# 2             _randallstephenson  Telecommunication Services
# 3                     _lewisbird      Consumer Discretionary
# 4                _douglaskessler                  Financials
# 5                    _kimcocklin                   Utilities
# 6                _thomasferguson                  Financials
# 7                   _tmpatterson                      Energy
# 8               _richardstockton                  Financials
# 9                  _wymanroberts      Consumer Discretionary
# 10                 _floydsherman                   Materials
# 11                _lawrencecohen                 Health Care
# 12              _dennissadlowski                 Industrials
# 13                     _markrohr                   Materials
# 14                     _joearmes                   Materials
# 15                    _ralphbabb                  Financials
# 16                  _userpicture                   Materials
# 17                     _jayadair                 Industrials
# 18                  _userpicture      Consumer Discretionary
# 19                _garywojtaszek                  Financials
# 20                  _danieljones                 Industrials
# 21                  _userpicture                     Energy
# 22                 _keithwalters      Consumer Discretionary
# 23                   _barrydavis                      Energy
# 24                  _userpicture                  Financials
# 25                  _userpicture                      Energy
# 26                  _darrenwoods                      Energy
# 27                _ronaldcogburn                  Technology
# 28                _randallstuewe            Consumer Staples
# 29                    _dondaseke                 Industrials
# ..                           ...                         ...
# 72                    _bradmason                 Health Care
# 73            _michaelwilloughby                  Technology
# 74                _alasdairjames      Consumer Discretionary
# 75                  _timothydove                      Energy
# 76                    _davidking                 Industrials
# 77               _jeffreyventura                      Energy
# 78                  _stephenwinn                 Technology
# 79                  _userpicture      Consumer Discretionary
# 80                   _stevengray                      Energy
# 81                    _seanmenke      Consumer Discretionary
# 82                  _userpicture      Consumer Discretionary
# 83                  _scottpowell                  Financials
# 84   _jamesanderson;_userpicture      Consumer Discretionary
# 85              _brucewilliamson                      Energy
# 86                    _garykelly      Consumer Discretionary
# 87                 _jacksonhsieh                  Financials
# 88            _ronaldrittenmeyer                 Health Care
# 89                     _ccargill                  Financials
# 90                _richtempleton      Consumer Discretionary
# 91                  _melissaraff      Consumer Discretionary
# 92                 _davidweinreb                  Financials
# 93                  _userpicture                  Financials
# 94                  _userpicture                   Financial
# 95                  _userpicture                 Industrials
# 96                  _userpicture            Consumer Staples
# 97                     _johnmarr                  Technology
# 98             _williamsandbrook                   Materials
# 99                  _userpicture                   Materials
# 100                _curtismorgan                   Utilities
# 101                  _kevinmiles      Consumer Discretionary
#
#                sectorfilter  \
# 0    consumer-discretionary
# 1    consumer-discretionary
# 2            communications
# 3    consumer-discretionary
# 4                financials
# 5                 utilities
# 6                financials
# 7                    energy
# 8                financials
# 9    consumer-discretionary
# 10                materials
# 11              health-care
# 12              industrials
# 13                materials
# 14                materials
# 15               financials
# 16                materials
# 17              industrials
# 18   consumer-discretionary
# 19               financials
# 20              industrials
# 21                   energy
# 22   consumer-discretionary
# 23                   energy
# 24               financials
# 25                   energy
# 26                   energy
# 27               technology
# 28         consumer-staples
# 29              industrials
# ..                      ...
# 72              health-care
# 73               technology
# 74   consumer-discretionary
# 75                   energy
# 76              industrials
# 77                   energy
# 78               technology
# 79   consumer-discretionary
# 80                   energy
# 81   consumer-discretionary
# 82   consumer-discretionary
# 83               financials
# 84   consumer-discretionary
# 85                   energy
# 86   consumer-discretionary
# 87               financials
# 88              health-care
# 89               financials
# 90   consumer-discretionary
# 91   consumer-discretionary
# 92               financials
# 93               financials
# 94               financials
# 95              industrials
# 96         consumer-staples
# 97               technology
# 98                materials
# 99                materials
# 100               utilities
# 101  consumer-discretionary
#
#                                                 source              undefined
# 0    https://www.sec.gov/Archives/edgar/data/110121...                    NaN
# 1    https://americanairlines.gcs-web.com/node/3348...                    NaN
# 2    https://investors.att.com/~/media/Files/A/ATT-...                    NaN
# 3    http://otp.investis.com/clients/us/at_home_gro...                    NaN
# 4                                                  NaN                    NaN
# 5    \nhttp://www.investquest.com/iq/a/ato/fin/prox...                    NaN
# 6    https://www.azz.com/sites/default/files/FY%202...                    NaN
# 7                                                  NaN                    NaN
# 8               http://www.snl.com/Cache/393619465.pdf                    NaN
# 9                                                  NaN                    NaN
# 10   http://investors.bldr.com/secfiling.cfm?filing...                    NaN
# 11   http://www.capitalsenior.com/sites/default/fil...                    NaN
# 12                                                 NaN                    NaN
# 13            http://www.snl.com/Cache/c392528425.html                    NaN
# 14                                                 NaN                    NaN
# 15                                                 NaN                    NaN
# 16   https://www.irpass.com/profiles/investor/PdfVi...                    NaN
# 17                                                 NaN                    NaN
# 18   http://phx.corporate-ir.net/phoenix.zhtml?c=19...                    NaN
# 19   http://investor.cyrusone.com/node/11191/html#t...                    NaN
# 20   https://www.sec.gov/Archives/edgar/data/850460...                    NaN
# 21   https://www.sec.gov/Archives/edgar/data/127618...  (President, see note)
# 22                                                 NaN                    NaN
# 23   https://www.sec.gov/Archives/edgar/data/117906...                    NaN
# 24                                                 NaN                    NaN
# 25                                                 NaN                    NaN
# 26                                                 NaN                    NaN
# 27   http://investors.exelatech.com/static-files/46...                    NaN
# 28   http://app.quotemedia.com/data/downloadFiling?...                    NaN
# 29   http://d18rn0p25nwr6d.cloudfront.net/CIK-00016...                    NaN
# ..                                                 ...                    ...
# 72                                                 NaN                    NaN
# 73                                                 NaN                    NaN
# 74   https://investors.pier1.com/static-files/7ff1c...                    NaN
# 75   http://investors.pxd.com/static-files/fca9fbb6...                    NaN
# 76   https://primorisservicescorporation.gcs-web.co...                    NaN
# 77   http://ir.rangeresources.com/phoenix.zhtml?c=1...                    NaN
# 78            http://www.snl.com/Cache/c393176810.html                    NaN
# 79   http://services.corporate-ir.net/SEC.Enhanced/...                    NaN
# 80                                                 NaN                    NaN
# 81   https://investors.sabre.com/static-files/20624...                    NaN
# 82   http://otp.investis.com/clients/us/sally_beaut...                    NaN
# 83   http://d18rn0p25nwr6d.cloudfront.net/CIK-00015...                    NaN
# 84   http://otp.investis.com/clients/us/sixflags1/S...                    NaN
# 85                                                 NaN                    NaN
# 86   https://www.sec.gov/Archives/edgar/data/92380/...                    NaN
# 87            http://www.snl.com/Cache/c393176341.html                    NaN
# 88   https://tenethealth.investorhq.businesswire.co...                    NaN
# 89            http://www.snl.com/Cache/c392506437.html                    NaN
# 90                                                 NaN                    NaN
# 91   http://d18rn0p25nwr6d.cloudfront.net/CIK-00014...                    NaN
# 92            http://www.snl.com/Cache/c392873877.html                    NaN
# 93   https://www.sec.gov/Archives/edgar/data/320335...                    NaN
# 94                                                 NaN                    NaN
# 95            http://www.snl.com/Cache/c392932802.html                    NaN
# 96                                                 NaN                    NaN
# 97   https://www.irpass.com/profiles/investor/SecB2...                    NaN
# 98                                                 NaN                    NaN
# 99   https://www.valhi.net/static-files/47c9f311-f3...                    NaN
# 100                                                NaN                    NaN
# 101                                                NaN                    NaN
#
# [102 rows x 13 columns]

# %% [markdown]
# Finding average of ceo pay in 2017 - need to exclude null values

# %%
ceo_complete = data.dropna(subset=['ceopay2017'])
ceo_complete['ceopay2017'].mean()
# Out:
# 6173417.138613861

# %% [markdown]
# Finding average of employee pay in 2017 - excluding null values

# %%
employee_complete = data.dropna(subset=['medianpay'])
employee_complete['medianpay'].mean()
# Out:
# 66735.93150684932

# %% [markdown]
# Finding median ceo pay in 2017 with excluded null values

# %%
ceo_complete['ceopay2017'].median()
# Out:
# 4515098.0

# %% [markdown]
# Finding average ceo pay by sector

# %%
cd = ceo_complete[ceo_complete.sectorfilter == 'consumer-discretionary']
communications = ceo_complete[ceo_complete.sectorfilter == 'communications']
financials = ceo_complete[ceo_complete.sectorfilter == 'financials']
utilities = ceo_complete[ceo_complete.sectorfilter == 'utilities']
energy = ceo_complete[ceo_complete.sectorfilter == 'energy']
# energy = ceo_complete[ceo_complete.sectorfilter == 'energy']
materials = ceo_complete[ceo_complete.sectorfilter == 'materials']
hc = ceo_complete[ceo_complete.sectorfilter == 'health-care']
industrials = ceo_complete[ceo_complete.sectorfilter == 'industrials']
technology = ceo_complete[ceo_complete.sectorfilter == 'technology']
cs = ceo_complete[ceo_complete.sectorfilter == 'consumer-staples']

# %%
sectors = [cd, communications, financials, utilities, energy, materials, hc, industrials, technology, cs]

# %%
for sector in sectors:
  print(sector.ceopay2017.mean())
# Out:
# 6226382.555555556
# 16364410.0
# 4983081.65
# 6341670.0
# 7770948.285714285
# 5364570.2
# 4752896.5
# 5230090.333333333
# 4104448.6
# 6403440.666666667

# %% [markdown]
# Find average of ceo to median pay ratios - exclude null values first

# %%
ratio_complete = data.dropna(subset=['employeeratio'])
ratio_complete.employeeratio.mean()
# Out:
# 174.1121917808219

# %% [markdown]
# Find median of ceo to median pay ratios

# %%
ratio_complete.employeeratio.median()
# Out:
# 92.0

# %% [markdown]
# Find average pay ratio by sector - exclude null ratio values first

# %%
r_cd = ratio_complete[ratio_complete.sectorfilter == 'consumer-discretionary']
r_communications = ratio_complete[ratio_complete.sectorfilter == 'communications']
r_financials = ratio_complete[ratio_complete.sectorfilter == 'financials']
r_utilities = ratio_complete[ratio_complete.sectorfilter == 'utilities']
r_energy = ratio_complete[ratio_complete.sectorfilter == 'energy']
r_materials = ratio_complete[ratio_complete.sectorfilter == 'materials']
r_hc = ratio_complete[ratio_complete.sectorfilter == 'health-care']
r_industrials = ratio_complete[ratio_complete.sectorfilter == 'industrials']
r_technology = ratio_complete[ratio_complete.sectorfilter == 'technology']
r_cs = ratio_complete[ratio_complete.sectorfilter == 'consumer-staples']

# %%
r_sectors = [r_cd, r_communications, r_financials, r_utilities, r_energy, r_materials, r_hc, r_industrials, r_technology, r_cs]

# %%
for r_sector in r_sectors:
  print(r_sector.employeeratio.mean())
# Out:
# 336.26
# 206.5
# 71.09266666666666
# nan
# 80.72727272727273
# 71.17142857142856
# 110.33333333333333
# 109.5
# 222.85
# 185.75

# %% [markdown]
# Find median pay ration by sector

# %%
for r_sector in r_sectors:
  print(r_sector.employeeratio.median())
# Out:
# 190.0
# 206.5
# 67.0
# nan
# 70.0
# 69.0
# 102.0
# 82.0
# 134.5
# 172.5
